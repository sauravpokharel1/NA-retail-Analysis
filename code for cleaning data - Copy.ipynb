# %%
import pandas as pd

df = pd.read_excel('Project 2 - Retail Sales Dataset (5).xlsx')
df.head()
# Out:
#   ORDER_NUMBER  SHIPMENT_NUMBER  ITEM_NUMBER INVOICE_NUMBER  INVOICE_DATE  \
# 0      6735217         20171129       428714        6735217      20171129
# 1      6165708         20190626       408872        6165708      20190626
# 2      6517073         20180910       354274        6517073      20180910
# 3      6723693         20200513       222679        6723693      20200513
# 4      6766514         20190128       431999        6766514      20190128
#
#    ORDER_DATE  CUSTOMER_NUMBER  CUSTOMER_LOCATION  CUSTOMER_DEPARTMENT  \
# 0    20171128              410                 10                    9
# 1    20190624             1375                  1                   83
# 2    20180908             2196                  1                   70
# 3    20200509             1934                 50                   70
# 4    20190125            75379                201                    0
#
#   CUSTOMER_PROVINCE  ... COMPANY_CODE       COMPANY_NAME COMPANY_NUMBER  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ORDER_NUMBER                10000 non-null  object
#  1   SHIPMENT_NUMBER             10000 non-null  int64
#  2   ITEM_NUMBER                 10000 non-null  int64
#  3   INVOICE_NUMBER              10000 non-null  object
#  4   INVOICE_DATE                10000 non-null  int64
#  5   ORDER_DATE                  10000 non-null  int64
#  6   CUSTOMER_NUMBER             10000 non-null  int64
#  7   CUSTOMER_LOCATION           10000 non-null  int64
#  8   CUSTOMER_DEPARTMENT         10000 non-null  int64
#  9   CUSTOMER_PROVINCE           10000 non-null  object
#  10  ITEM_DESCRIPTION            9928 non-null   object
#  11  SHIPPING_REGION_IDENTIFIER  10000 non-null  int64
#  12  SHIPPING_REGION_CODE        10000 non-null  object
# ...

# %%
df.drop(['SHIPMENT_NUMBER','INVOICE_NUMBER','CUSTOMER_DEPARTMENT','SHIPPING_REGION_IDENTIFIER','SHIPPING_REGION_CODE','SHIPPING_REGION_NAME','SHIPPING_UNIT_MEASURE','SHIPPING_PACK_QUANTITY'
,'ITEM_SECTION_MODULE','ITEM_GROUP','ITEM_SEQUENCE','ITEM_STOCK_STATUS','WAREHOUSE_IDENTIFIER','WAREHOUSE_NUMBER','WAREHOUSE_NAME','WAREHOUSE_REGION_NAME','VENDOR_IDENTIFIER','VENDOR_NUMBER','VENDOR_NAME',
'VENDOR_CITY','VENDOR_COUNTRY','VENDOR_ADDRESS','SHIPPED_QUANTITY','COMPANY_IDENTIFIER','COMPANY_CODE'
,'COMPANY_NUMBER','UPC_NUMBER','PURCHASE_ORDER_NUMBER']
, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        10000 non-null  object
#  1   ITEM_NUMBER         10000 non-null  int64
#  2   INVOICE_DATE        10000 non-null  int64
#  3   ORDER_DATE          10000 non-null  int64
#  4   CUSTOMER_NUMBER     10000 non-null  int64
#  5   CUSTOMER_LOCATION   10000 non-null  int64
#  6   CUSTOMER_PROVINCE   10000 non-null  object
#  7   ITEM_DESCRIPTION    9928 non-null   object
#  8   ITEM_UNIT_QUANTITY  10000 non-null  float64
#  9   ITEM_DEPARTMENT     10000 non-null  int64
#  10  ITEM_SECTION        10000 non-null  int64
#  11  ORDER_QUANTITY      10000 non-null  int64
#  12  COMPANY_NAME        10000 non-null  object
#  13  AVERAGE_COST_PRICE  10000 non-null  float64
#  14  SALES_AMOUNT        10000 non-null  float64
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9928 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        9928 non-null   object
#  1   ITEM_NUMBER         9928 non-null   int64
#  2   INVOICE_DATE        9928 non-null   int64
#  3   ORDER_DATE          9928 non-null   int64
#  4   CUSTOMER_NUMBER     9928 non-null   int64
#  5   CUSTOMER_LOCATION   9928 non-null   int64
#  6   CUSTOMER_PROVINCE   9928 non-null   object
#  7   ITEM_DESCRIPTION    9928 non-null   object
#  8   ITEM_UNIT_QUANTITY  9928 non-null   float64
#  9   ITEM_DEPARTMENT     9928 non-null   int64
#  10  ITEM_SECTION        9928 non-null   int64
#  11  ORDER_QUANTITY      9928 non-null   int64
#  12  COMPANY_NAME        9928 non-null   object
#  13  AVERAGE_COST_PRICE  9928 non-null   float64
#  14  SALES_AMOUNT        9928 non-null   float64
# ...

# %%
df.to_excel("cleaned_retail.xlsx", index = False)
