# %%
#cleaning outliers
import pandas as pd
main_data = pd.read_excel('cleaned_retail.xlsx')

# %%
main_data.head()
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        10000 non-null  object
#  1   ITEM_NUMBER         10000 non-null  int64
#  2   INVOICE_DATE        10000 non-null  int64
#  3   ORDER_DATE          10000 non-null  int64
#  4   CUSTOMER_NUMBER     10000 non-null  int64
#  5   CUSTOMER_LOCATION   10000 non-null  int64
#  6   CUSTOMER_PROVINCE   10000 non-null  object
#  7   ITEM_DESCRIPTION    9928 non-null   object
#  8   ITEM_UNIT_QUANTITY  10000 non-null  float64
#  9   ITEM_DEPARTMENT     10000 non-null  int64
#  10  ITEM_SECTION        10000 non-null  int64
#  11  ORDER_QUANTITY      10000 non-null  int64
#  12  COMPANY_NAME        10000 non-null  object
#  13  AVERAGE_COST_PRICE  10000 non-null  float64
#  14  SALES_AMOUNT        10000 non-null  float64
# ...

# %%
outliers = pd.read_csv('outliers.csv')
outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company Name        682 non-null    object
#  1   Customer Location   682 non-null    int64
#  2   Customer Number     682 non-null    int64
#  3   Customer Province   674 non-null    object
#  4   Invoice Date        682 non-null    object
#  5   Item Description    682 non-null    object
#  6   Item Number         682 non-null    int64
#  7   Order Date          682 non-null    object
#  8   Order Number        670 non-null    float64
#  9   Order Type          682 non-null    object
#  10  Average Cost Price  682 non-null    float64
#  11  Cost Price          682 non-null    float64
#  12  Invoice Amount      682 non-null    float64
#  13  Item Department     682 non-null    int64
#  14  Item Section        682 non-null    int64
# ...

# %%
main_data.reset_index(drop=True)
# Out:
#      ORDER_NUMBER  SHIPMENT_NUMBER  ITEM_NUMBER INVOICE_NUMBER  INVOICE_DATE  \
# 0         6735217         20171129       428714        6735217      20171129
# 1         6165708         20190626       408872        6165708      20190626
# 2         6517073         20180910       354274        6517073      20180910
# 3         6723693         20200513       222679        6723693      20200513
# 4         6766514         20190128       431999        6766514      20190128
# ...           ...              ...          ...            ...           ...
# 9995      5100802         20190403       522110        5100802      20190403
# 9996      5462559         20200827      4745048        5462559      20200827
# 9997      5165659         20190708       620658        5165659      20190708
# 9998      3274935         20200801       177550        3274935      20200801
# 9999      6104799         20201129       398867        6104799      20201129
#
# ...

# %%
outliers.reset_index(drop=True)
# Out:
#           Company Name  Customer Location  Customer Number Customer Province  \
# 0    BRANDS GLOBAL CO.                  5              208             TEXAS
# 1    BRANDS GLOBAL CO.                  6             2754        CALIFORNIA
# 2    BRANDS GLOBAL CO.                  1             6868           ARIZONA
# 3    BRANDS GLOBAL CO.                  6             2300        CALIFORNIA
# 4    BRANDS GLOBAL CO.                 25             2486             TEXAS
# ..                 ...                ...              ...               ...
# 707  BRANDS GLOBAL CO.                 33             2438             TEXAS
# 708  BRANDS GLOBAL CO.                  6             2312           ARIZONA
# 709  BRANDS GLOBAL CO.                  6             1811             TEXAS
# 710  BRANDS GLOBAL CO.                 15             1819             TEXAS
# 711  BRANDS GLOBAL CO.                  1             2806        CALIFORNIA
#
# ...

# %%
main_data = main_data[~main_data['ORDER_NUMBER'].isin(outliers['Order Number'])]

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9250 entries, 0 to 9927
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ORDER_NUMBER        9250 non-null   object
#  1   ITEM_NUMBER         9250 non-null   int64
#  2   INVOICE_DATE        9250 non-null   int64
#  3   ORDER_DATE          9250 non-null   int64
#  4   CUSTOMER_NUMBER     9250 non-null   int64
#  5   CUSTOMER_LOCATION   9250 non-null   int64
#  6   CUSTOMER_PROVINCE   9250 non-null   object
#  7   ITEM_DESCRIPTION    9250 non-null   object
#  8   ITEM_UNIT_QUANTITY  9250 non-null   float64
#  9   ITEM_DEPARTMENT     9250 non-null   int64
#  10  ITEM_SECTION        9250 non-null   int64
#  11  ORDER_QUANTITY      9250 non-null   int64
#  12  COMPANY_NAME        9250 non-null   object
#  13  AVERAGE_COST_PRICE  9250 non-null   float64
#  14  SALES_AMOUNT        9250 non-null   float64
# ...

# %%
main_data.to_excel("no_outliers.xlsx")

# %% [markdown]
# # Dropping columns
